# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_return_path = Path("Resources/whale_returns.csv")
whale_returns = pd.read_csv(whale_return_path, parse_dates=True, index_col='Date', infer_datetime_format=True)

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna()
whale_returns.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_path = Path("Resources/algo_returns.csv")
algo_returns = pd.read_csv(algo_returns_path,  parse_dates=True, index_col='Date',infer_datetime_format=True)

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns = algo_returns.dropna()
algo_returns.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_path = Path("Resources/sp500_history.csv")
sp500_history = pd.read_csv(sp500_history_path, parse_dates=True,index_col='Date', infer_datetime_format=True)
sp500_history.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history = pd.read_csv(sp500_history_path, parse_dates=True, index_col='Date', infer_datetime_format=True, converters={'Close': lambda s: float(s.replace('$', ''))})
sp500_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_returns = sp500_history['Close'].pct_change()
sp500_returns.head()
# Out:
# Date
# 2019-04-23         NaN
# 2019-04-22   -0.008764
# 2019-04-18   -0.001011
# 2019-04-17   -0.001577
# 2019-04-16    0.002279
# Name: Close, dtype: float64

# %%
# Drop nulls
sp500_returns = sp500_returns.dropna()
sp500_returns.count()
# Out:
# 1648

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns = sp500_returns.rename("S&P 500")
sp500_returns.head()
# Out:
# Date
# 2019-04-22   -0.008764
# 2019-04-18   -0.001011
# 2019-04-17   -0.001577
# 2019-04-16    0.002279
# 2019-04-15   -0.000509
# Name: S&P 500, dtype: float64

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

joint_returns = pd.concat([whale_returns, algo_returns, sp500_returns], axis=1, join='inner').dropna()
joint_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
joint_returns.plot(kind='line', title='All Portfolio Returns', legend
                   =True, figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'All Portfolio Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = joint_returns.sum()
# Plot cumulative returns
cumulative_returns.plot.bar(title='Cumulative Returns of All Portfolios')
cumulative_returns.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.177723
# PAULSON & CO.INC.             -0.226621
# TIGER GLOBAL MANAGEMENT LLC   -0.093122
# BERKSHIRE HATHAWAY INC         0.514508
# Algo 1                         0.685277
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
whale_returns.boxplot(figsize=(15,7))
# Out:
# <AxesSubplot:>

# %%
algo_returns.boxplot(figsize=(7,7))
# Out:
# <AxesSubplot:>

# %%
joint_returns.boxplot(figsize=(20,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
whale_std = whale_returns.std()
algo_std  = algo_returns.std()

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = sp500_returns.std()
# Determine which portfolios are riskier than the S&P 500
std_list = [whale_std, algo_std, sp500_std]
std_list
# Out:
# [SOROS FUND MANAGEMENT LLC      0.007842
#  PAULSON & CO.INC.              0.006977
#  TIGER GLOBAL MANAGEMENT LLC    0.010824
#  BERKSHIRE HATHAWAY INC         0.012831
#  dtype: float64,
#  Algo 1    0.007988
#  Algo 2    0.008466
#  dtype: float64,
#  0.008134642617809523]

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
whale_std = whale_returns.std()* np.sqrt(252)
algo_std  = algo_returns.std()* np.sqrt(252)
sp500_std = sp500_returns.std()*np.sqrt(252)
std_list = [whale_std, algo_std, sp500_std]
std_list
# Out:
# [SOROS FUND MANAGEMENT LLC      0.124487
#  PAULSON & CO.INC.              0.110754
#  TIGER GLOBAL MANAGEMENT LLC    0.171830
#  BERKSHIRE HATHAWAY INC         0.203682
#  dtype: float64,
#  Algo 1    0.126801
#  Algo 2    0.134401
#  dtype: float64,
#  0.12913344822666864]

# %%
print(f"The portfolios riskier than the S&P 500 are: Tiger Gloabl Management LLC, Berkshire Hathaway INC, and Algo 2")
# Out:
# The portfolios riskier than the S&P 500 are: Tiger Gloabl Management LLC, Berkshire Hathaway INC, and Algo 2

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
joint_returns.rolling(window=21).std().plot(figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_df = joint_returns.corr()
# Display de correlation matrix
sns.heatmap(correlation_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
algo_cov = joint_returns['Algo 1'].cov(joint_returns['S&P 500'])
rolling_algo_cov = joint_returns['Algo 1'].rolling(window=30).cov(joint_returns['S&P 500'])

# Calculate variance of S&P 500
sp500_var = joint_returns['S&P 500'].var()
rolling_var = joint_returns['S&P 500'].rolling(window=30).var()
# Computing beta
algo_beta = algo_cov/sp500_var
rolling_algo_beta = rolling_algo_cov/rolling_var
# Plot beta trend
rolling_algo_beta.plot(figsize=(20,10), title='Rolling 30-Day Beta of Algo 1 Returns and S&P 500')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of Algo 1 Returns and S&P 500'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (joint_returns.mean()*252)/(joint_returns.std()*np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar', title='Sharpe Ratios of All Portfolios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios of All Portfolios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!
# The Algo 1 strategy outperforms both the market and whales portfolio

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
apple_path = Path("Resources/aapl_historical.csv")
apple_histoical = pd.read_csv(apple_path, parse_dates=True, index_col='Trade DATE', infer_datetime_format=True)
apple_histoical.rename(columns={ "NOCP": "Apple"}, inplace=True)
apple_histoical.head()
# Out:
#            Symbol   Apple
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Reading data from 2nd stock
cost_path = Path("Resources/cost_historical.csv")
cost_histoical = pd.read_csv(cost_path, parse_dates=True, index_col='Trade DATE', infer_datetime_format=True)
cost_histoical.rename(columns={"NOCP": "Cost"}, inplace=True)
cost_histoical.head()
# Out:
#            Symbol    Cost
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Reading data from 3rd stock
goog_path = Path("Resources/goog_historical.csv")
goog_historical = pd.read_csv(goog_path, parse_dates=True, index_col='Trade DATE', infer_datetime_format=True)
goog_historical.rename(columns={"NOCP": "Google"}, inplace=True)
goog_historical.head()
# Out:
#            Symbol   Google
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Combine all stocks in a single DataFrame
combined_stocks = pd.concat([apple_histoical, cost_histoical, goog_historical], axis=1, join='outer')
combined_stocks.head()
# Out:
#            Symbol   Apple Symbol    Cost Symbol   Google
# Trade DATE
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40

# %%
# Reset Date index
combined_stocks.index.names=['Date']
combined_stocks.head()
# Out:
#            Symbol   Apple Symbol    Cost Symbol   Google
# Date
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40

# %%
# Reorganize portfolio data by having a column per symbol
combined_stocks = combined_stocks.drop(columns=['Symbol'], axis=1)

# %%
# Calculate daily returns # Drop NAs
combined_returns = combined_stocks.pct_change().dropna()
# Display sample data
combined_returns.head()
# Out:
#                Apple      Cost    Google
# Date
# 2019-05-08  0.010861 -0.008749  0.003347
# 2019-05-07 -0.000197 -0.004806  0.006714
# 2019-05-06  0.027704  0.016862  0.013023
# 2019-05-03  0.015685  0.001597 -0.003355
# 2019-05-02 -0.012279 -0.007890 -0.019226

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
finished_returns = combined_returns.dot(weights)
# Display sample data

finished_returns.head()
# Out:
# Date
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
joint_returns = pd.concat([joint_returns, finished_returns], join='inner', axis=1)

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
joint_returns.dropna(inplace=True)
joint_returns.columns=['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC', 'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1', 'Algo 2', 'S&P 500', 'Custom']
joint_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC  \
# Date
# 2018-05-11                  -0.004717          0.000982
# 2018-05-14                   0.000000          0.000000
# 2018-05-15                  -0.000726         -0.001409
# 2018-05-16                   0.008637          0.006244
# 2018-05-17                  -0.001955          0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2   S&P 500    Custom
# Date
# 2018-05-11  0.000281 -0.000883 -0.000012
# 2018-05-14  0.001635  0.006889  0.010216
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
new_joint_std = joint_returns.std()
new_joint_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.009234
# PAULSON & CO.INC               0.007350
# TIGER GLOBAL MANAGEMENT LLC    0.014642
# BERKSHIRE HATHAWAY INC         0.015548
# Algo 1                         0.008419
# Algo 2                         0.008769
# S&P 500                        0.009584
# Custom                         0.013426
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation
joint_returns.rolling(window=21).std().plot(figsize=(25,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
sns.heatmap(joint_returns.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
rolling_custom_cov = joint_returns['Custom'].rolling(window=60).cov(joint_returns['S&P 500'])

# Calculate variance of S&P 500

rolling_var = joint_returns['S&P 500'].rolling(window=60).var()

# Computing beta
custom_beta = rolling_custom_cov/rolling_var

# Plot beta trend
custom_beta.plot(figsize=(20,10), title='Rolling 30-Day Beta of Custom Returns and S&P 500')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of Custom Returns and S&P 500'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

new_sharpe_ratios = (joint_returns.mean()*252)/(joint_returns.std()*np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
new_sharpe_ratios.plot(kind='bar', title='Sharpe Ratios of All Portfolios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios of All Portfolios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
'''My new Custom portfolio under performed during the respective time frame. It looks like Algo 1 did even better during this shorten time frame'''
# Out:
# 'My new Custom portfolio under performed during the respective time frame. It looks like Algo 1 did even better during this shorten time frame'
